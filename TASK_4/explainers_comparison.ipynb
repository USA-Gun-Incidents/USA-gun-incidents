# %% [markdown]
# **Data mining Project - University of Pisa, acedemic year 2023/24**
# **Authors**: Giacomo Aru, Giulia Ghisolfi, Luca Marini, Irene Testa
# # Explaination scores

# %%
import pandas as pd

# %%
# faithfulness on selected records (post-hoc explainers)

lime_faithfulness_selected_df = pd.read_csv('../data/explanation_results/lime_faithfulness_selected_records.csv', index_col=0)
shap_faithfulness_selected_df= pd.read_csv('../data/explanation_results/shap_faithfulness_selected_records.csv', index_col=0)

lime_faithfulness_selected_df.columns = pd.MultiIndex.from_product([lime_faithfulness_selected_df.columns, ['lime']])
shap_faithfulness_selected_df.columns = pd.MultiIndex.from_product([shap_faithfulness_selected_df.columns, ['shap']])
lime_faithfulness_selected_df.join(shap_faithfulness_selected_df).sort_index(level=0, axis=1)
# Out:
#                                                    DecisionTreeClassifier  \
#                                                                      lime
# Attempted Suicide                                                0.638216
# Mass shooting                                                    0.734065
# Fatal with highest confidence by DecisionTreeCl...              -0.143784
# Fatal with highest confidence by NeuralNetworkC...               0.661191
# Fatal with highest confidence by RandomForestCl...               0.715922
# Fatal with highest confidence by NaiveBayesMixe...               0.679619
# Fatal with highest confidence by SupportVectorM...               0.048304
# Fatal with highest confidence by TabNetClassifier                0.191683
# Fatal with highest confidence by ExtremeGradien...               0.680731
# Non-Fatal with highest confidence by DecisionTr...               0.380304
# Non-Fatal with highest confidence by NeuralNetw...               0.304621
# Non-Fatal with highest confidence by RandomFore...               0.368766
# Non-Fatal with highest confidence by NaiveBayes...               0.004983
# Non-Fatal with highest confidence by SupportVec...               0.113793
# Non-Fatal with highest confidence by TabNetClas...               0.262421
# Non-Fatal with highest confidence by ExtremeGra...              -0.391588
#
#                                                               \
#                                                         shap
# Attempted Suicide                                   0.963508
# Mass shooting                                       0.977253
# Fatal with highest confidence by DecisionTreeCl...  0.762704
# Fatal with highest confidence by NeuralNetworkC...  0.977253
# Fatal with highest confidence by RandomForestCl...  0.980199
# Fatal with highest confidence by NaiveBayesMixe...  0.978704
# Fatal with highest confidence by SupportVectorM...  0.349155
# Fatal with highest confidence by TabNetClassifier   0.823683
# Fatal with highest confidence by ExtremeGradien...  0.966861
# Non-Fatal with highest confidence by DecisionTr... -0.929084
# Non-Fatal with highest confidence by NeuralNetw... -0.711646
# Non-Fatal with highest confidence by RandomFore... -0.794060
# Non-Fatal with highest confidence by NaiveBayes... -0.467325
# Non-Fatal with highest confidence by SupportVec... -0.840387
# Non-Fatal with highest confidence by TabNetClas...  0.694946
# Non-Fatal with highest confidence by ExtremeGra...  0.697630
#
#                                                    ExtremeGradientBoostingClassifier  \
#                                                                                 lime
# Attempted Suicide                                                           0.545138
# Mass shooting                                                               0.571016
# Fatal with highest confidence by DecisionTreeCl...                          0.189934
# Fatal with highest confidence by NeuralNetworkC...                          0.560756
# Fatal with highest confidence by RandomForestCl...                          0.590276
# Fatal with highest confidence by NaiveBayesMixe...                          0.307952
# Fatal with highest confidence by SupportVectorM...                          0.032596
# Fatal with highest confidence by TabNetClassifier                           0.155621
# Fatal with highest confidence by ExtremeGradien...                          0.599138
# Non-Fatal with highest confidence by DecisionTr...                          0.412477
# Non-Fatal with highest confidence by NeuralNetw...                          0.436162
# Non-Fatal with highest confidence by RandomFore...                          0.388899
# Non-Fatal with highest confidence by NaiveBayes...                          0.153054
# Non-Fatal with highest confidence by SupportVec...                          0.139134
# Non-Fatal with highest confidence by TabNetClas...                          0.237959
# Non-Fatal with highest confidence by ExtremeGra...                          0.431065
#
#                                                               \
#                                                         shap
# Attempted Suicide                                   0.979389
# Mass shooting                                       0.918252
# Fatal with highest confidence by DecisionTreeCl... -0.558125
# Fatal with highest confidence by NeuralNetworkC...  0.918252
# Fatal with highest confidence by RandomForestCl...  0.964750
# Fatal with highest confidence by NaiveBayesMixe... -0.730238
# Fatal with highest confidence by SupportVectorM...  0.779718
# Fatal with highest confidence by TabNetClassifier   0.842501
# Fatal with highest confidence by ExtremeGradien...  0.953075
# Non-Fatal with highest confidence by DecisionTr... -0.965275
# Non-Fatal with highest confidence by NeuralNetw... -0.908356
# Non-Fatal with highest confidence by RandomFore... -0.955820
# Non-Fatal with highest confidence by NaiveBayes... -0.592617
# Non-Fatal with highest confidence by SupportVec... -0.853630
# Non-Fatal with highest confidence by TabNetClas... -0.685433
# Non-Fatal with highest confidence by ExtremeGra... -0.887615
#
#                                                    NeuralNetworkClassifier  \
#                                                                       lime
# Attempted Suicide                                                -0.049704
# Mass shooting                                                    -0.212902
# Fatal with highest confidence by DecisionTreeCl...                0.050865
# Fatal with highest confidence by NeuralNetworkC...               -0.219692
# Fatal with highest confidence by RandomForestCl...               -0.175269
# Fatal with highest confidence by NaiveBayesMixe...                0.018901
# Fatal with highest confidence by SupportVectorM...               -0.059077
# Fatal with highest confidence by TabNetClassifier                -0.068863
# Fatal with highest confidence by ExtremeGradien...               -0.149152
# Non-Fatal with highest confidence by DecisionTr...                0.157702
# Non-Fatal with highest confidence by NeuralNetw...                0.072044
# Non-Fatal with highest confidence by RandomFore...                0.144798
# Non-Fatal with highest confidence by NaiveBayes...               -0.073324
# Non-Fatal with highest confidence by SupportVec...                0.051220
# Non-Fatal with highest confidence by TabNetClas...                0.088674
# Non-Fatal with highest confidence by ExtremeGra...               -0.016043
#
#                                                               \
#                                                         shap
# Attempted Suicide                                   0.130451
# Mass shooting                                      -0.037200
# Fatal with highest confidence by DecisionTreeCl... -0.442505
# Fatal with highest confidence by NeuralNetworkC... -0.033473
# Fatal with highest confidence by RandomForestCl...  0.126164
# Fatal with highest confidence by NaiveBayesMixe...  0.279117
# Fatal with highest confidence by SupportVectorM...  0.449277
# Fatal with highest confidence by TabNetClassifier  -0.041036
# Fatal with highest confidence by ExtremeGradien...  0.047637
# Non-Fatal with highest confidence by DecisionTr... -0.226454
# Non-Fatal with highest confidence by NeuralNetw... -0.018091
# Non-Fatal with highest confidence by RandomFore... -0.181697
# Non-Fatal with highest confidence by NaiveBayes...  0.214185
# Non-Fatal with highest confidence by SupportVec... -0.052365
# Non-Fatal with highest confidence by TabNetClas... -0.207670
# Non-Fatal with highest confidence by ExtremeGra...  0.074321
#
#                                                    RandomForestClassifier  \
#                                                                      lime
# Attempted Suicide                                                0.604192
# Mass shooting                                                    0.682913
# Fatal with highest confidence by DecisionTreeCl...               0.249907
# Fatal with highest confidence by NeuralNetworkC...               0.695583
# Fatal with highest confidence by RandomForestCl...               0.676820
# Fatal with highest confidence by NaiveBayesMixe...               0.634699
# Fatal with highest confidence by SupportVectorM...               0.017421
# Fatal with highest confidence by TabNetClassifier                0.238933
# Fatal with highest confidence by ExtremeGradien...               0.664125
# Non-Fatal with highest confidence by DecisionTr...               0.483481
# Non-Fatal with highest confidence by NeuralNetw...               0.432901
# Non-Fatal with highest confidence by RandomFore...               0.495323
# Non-Fatal with highest confidence by NaiveBayes...               0.438715
# Non-Fatal with highest confidence by SupportVec...               0.139607
# Non-Fatal with highest confidence by TabNetClas...               0.445155
# Non-Fatal with highest confidence by ExtremeGra...               0.541675
#
#                                                               \
#                                                         shap
# Attempted Suicide                                   0.964190
# Mass shooting                                       0.964476
# Fatal with highest confidence by DecisionTreeCl... -0.801124
# Fatal with highest confidence by NeuralNetworkC...  0.964476
# Fatal with highest confidence by RandomForestCl...  0.971303
# Fatal with highest confidence by NaiveBayesMixe...  0.972414
# Fatal with highest confidence by SupportVectorM...  0.128338
# Fatal with highest confidence by TabNetClassifier   0.824253
# Fatal with highest confidence by ExtremeGradien...  0.963553
# Non-Fatal with highest confidence by DecisionTr... -0.957459
# Non-Fatal with highest confidence by NeuralNetw... -0.812596
# Non-Fatal with highest confidence by RandomFore... -0.951173
# Non-Fatal with highest confidence by NaiveBayes... -0.811847
# Non-Fatal with highest confidence by SupportVec... -0.773380
# Non-Fatal with highest confidence by TabNetClas... -0.788266
# Non-Fatal with highest confidence by ExtremeGra... -0.877779
#
#                                                    SupportVectorMachineClassifier  \
#                                                                              lime
# Attempted Suicide                                                       -0.049129
# Mass shooting                                                           -0.037180
# Fatal with highest confidence by DecisionTreeCl...                       0.062525
# Fatal with highest confidence by NeuralNetworkC...                      -0.019645
# Fatal with highest confidence by RandomForestCl...                      -0.133346
# Fatal with highest confidence by NaiveBayesMixe...                      -0.100839
# Fatal with highest confidence by SupportVectorM...                      -0.078551
# Fatal with highest confidence by TabNetClassifier                       -0.066701
# Fatal with highest confidence by ExtremeGradien...                      -0.151222
# Non-Fatal with highest confidence by DecisionTr...                       0.150209
# Non-Fatal with highest confidence by NeuralNetw...                      -0.089336
# Non-Fatal with highest confidence by RandomFore...                       0.210072
# Non-Fatal with highest confidence by NaiveBayes...                       0.073212
# Non-Fatal with highest confidence by SupportVec...                       0.097364
# Non-Fatal with highest confidence by TabNetClas...                       0.097356
# Non-Fatal with highest confidence by ExtremeGra...                       0.168056
#
#
#                                                         shap
# Attempted Suicide                                  -0.235384
# Mass shooting                                       0.298565
# Fatal with highest confidence by DecisionTreeCl... -0.023103
# Fatal with highest confidence by NeuralNetworkC...  0.304121
# Fatal with highest confidence by RandomForestCl...  0.169740
# Fatal with highest confidence by NaiveBayesMixe... -0.119068
# Fatal with highest confidence by SupportVectorM... -0.409537
# Fatal with highest confidence by TabNetClassifier   0.338707
# Fatal with highest confidence by ExtremeGradien... -0.230260
# Non-Fatal with highest confidence by DecisionTr... -0.081196
# Non-Fatal with highest confidence by NeuralNetw...  0.051093
# Non-Fatal with highest confidence by RandomFore... -0.143239
# Non-Fatal with highest confidence by NaiveBayes... -0.030693
# Non-Fatal with highest confidence by SupportVec... -0.186853
# Non-Fatal with highest confidence by TabNetClas...  0.331711
# Non-Fatal with highest confidence by ExtremeGra... -0.111436

# %%
# monotonicity on selected records (post-hoc explainers)

lime_monotonicity_selected_df = pd.read_csv('../data/explanation_results/lime_monotonicity_selected_records.csv', index_col=0)
shap_monotonicity_selected_df = pd.read_csv('../data/explanation_results/shap_monotonicity_selected_records.csv', index_col=0)

lime_monotonicity_selected_df.columns = pd.MultiIndex.from_product([lime_monotonicity_selected_df.columns, ['lime']])
shap_monotonicity_selected_df.columns = pd.MultiIndex.from_product([shap_monotonicity_selected_df.columns, ['shap']])
lime_monotonicity_selected_df.join(shap_monotonicity_selected_df).sort_index(level=0, axis=1)
# Out:
#                                                    DecisionTreeClassifier  \
#                                                                      lime
# Attempted Suicide                                                    True
# Mass shooting                                                        True
# Fatal with highest confidence by DecisionTreeCl...                  False
# Fatal with highest confidence by NeuralNetworkC...                   True
# Fatal with highest confidence by RandomForestCl...                   True
# Fatal with highest confidence by NaiveBayesMixe...                  False
# Fatal with highest confidence by SupportVectorM...                  False
# Fatal with highest confidence by TabNetClassifier                   False
# Fatal with highest confidence by ExtremeGradien...                  False
# Non-Fatal with highest confidence by DecisionTr...                  False
# Non-Fatal with highest confidence by NeuralNetw...                  False
# Non-Fatal with highest confidence by RandomFore...                  False
# Non-Fatal with highest confidence by NaiveBayes...                  False
# Non-Fatal with highest confidence by SupportVec...                   True
# Non-Fatal with highest confidence by TabNetClas...                  False
# Non-Fatal with highest confidence by ExtremeGra...                  False
#
#                                                            \
#                                                      shap
# Attempted Suicide                                    True
# Mass shooting                                        True
# Fatal with highest confidence by DecisionTreeCl...  False
# Fatal with highest confidence by NeuralNetworkC...   True
# Fatal with highest confidence by RandomForestCl...   True
# Fatal with highest confidence by NaiveBayesMixe...  False
# Fatal with highest confidence by SupportVectorM...  False
# Fatal with highest confidence by TabNetClassifier   False
# Fatal with highest confidence by ExtremeGradien...   True
# Non-Fatal with highest confidence by DecisionTr...   True
# Non-Fatal with highest confidence by NeuralNetw...  False
# Non-Fatal with highest confidence by RandomFore...   True
# Non-Fatal with highest confidence by NaiveBayes...  False
# Non-Fatal with highest confidence by SupportVec...   True
# Non-Fatal with highest confidence by TabNetClas...   True
# Non-Fatal with highest confidence by ExtremeGra...   True
#
#                                                    ExtremeGradientBoostingClassifier  \
#                                                                                 lime
# Attempted Suicide                                                              False
# Mass shooting                                                                  False
# Fatal with highest confidence by DecisionTreeCl...                             False
# Fatal with highest confidence by NeuralNetworkC...                             False
# Fatal with highest confidence by RandomForestCl...                             False
# Fatal with highest confidence by NaiveBayesMixe...                             False
# Fatal with highest confidence by SupportVectorM...                             False
# Fatal with highest confidence by TabNetClassifier                              False
# Fatal with highest confidence by ExtremeGradien...                             False
# Non-Fatal with highest confidence by DecisionTr...                             False
# Non-Fatal with highest confidence by NeuralNetw...                             False
# Non-Fatal with highest confidence by RandomFore...                             False
# Non-Fatal with highest confidence by NaiveBayes...                             False
# Non-Fatal with highest confidence by SupportVec...                             False
# Non-Fatal with highest confidence by TabNetClas...                             False
# Non-Fatal with highest confidence by ExtremeGra...                             False
#
#                                                            \
#                                                      shap
# Attempted Suicide                                   False
# Mass shooting                                       False
# Fatal with highest confidence by DecisionTreeCl...  False
# Fatal with highest confidence by NeuralNetworkC...  False
# Fatal with highest confidence by RandomForestCl...  False
# Fatal with highest confidence by NaiveBayesMixe...  False
# Fatal with highest confidence by SupportVectorM...  False
# Fatal with highest confidence by TabNetClassifier   False
# Fatal with highest confidence by ExtremeGradien...  False
# Non-Fatal with highest confidence by DecisionTr...  False
# Non-Fatal with highest confidence by NeuralNetw...  False
# Non-Fatal with highest confidence by RandomFore...  False
# Non-Fatal with highest confidence by NaiveBayes...  False
# Non-Fatal with highest confidence by SupportVec...  False
# Non-Fatal with highest confidence by TabNetClas...  False
# Non-Fatal with highest confidence by ExtremeGra...  False
#
#                                                    NeuralNetworkClassifier  \
#                                                                       lime
# Attempted Suicide                                                     True
# Mass shooting                                                         True
# Fatal with highest confidence by DecisionTreeCl...                   False
# Fatal with highest confidence by NeuralNetworkC...                    True
# Fatal with highest confidence by RandomForestCl...                    True
# Fatal with highest confidence by NaiveBayesMixe...                    True
# Fatal with highest confidence by SupportVectorM...                    True
# Fatal with highest confidence by TabNetClassifier                     True
# Fatal with highest confidence by ExtremeGradien...                    True
# Non-Fatal with highest confidence by DecisionTr...                   False
# Non-Fatal with highest confidence by NeuralNetw...                   False
# Non-Fatal with highest confidence by RandomFore...                   False
# Non-Fatal with highest confidence by NaiveBayes...                   False
# Non-Fatal with highest confidence by SupportVec...                   False
# Non-Fatal with highest confidence by TabNetClas...                   False
# Non-Fatal with highest confidence by ExtremeGra...                   False
#
#                                                            \
#                                                      shap
# Attempted Suicide                                    True
# Mass shooting                                       False
# Fatal with highest confidence by DecisionTreeCl...  False
# Fatal with highest confidence by NeuralNetworkC...  False
# Fatal with highest confidence by RandomForestCl...   True
# Fatal with highest confidence by NaiveBayesMixe...   True
# Fatal with highest confidence by SupportVectorM...   True
# Fatal with highest confidence by TabNetClassifier   False
# Fatal with highest confidence by ExtremeGradien...  False
# Non-Fatal with highest confidence by DecisionTr...  False
# Non-Fatal with highest confidence by NeuralNetw...  False
# Non-Fatal with highest confidence by RandomFore...  False
# Non-Fatal with highest confidence by NaiveBayes...  False
# Non-Fatal with highest confidence by SupportVec...  False
# Non-Fatal with highest confidence by TabNetClas...  False
# Non-Fatal with highest confidence by ExtremeGra...  False
#
#                                                    RandomForestClassifier  \
#                                                                      lime
# Attempted Suicide                                                   False
# Mass shooting                                                       False
# Fatal with highest confidence by DecisionTreeCl...                  False
# Fatal with highest confidence by NeuralNetworkC...                  False
# Fatal with highest confidence by RandomForestCl...                  False
# Fatal with highest confidence by NaiveBayesMixe...                  False
# Fatal with highest confidence by SupportVectorM...                  False
# Fatal with highest confidence by TabNetClassifier                   False
# Fatal with highest confidence by ExtremeGradien...                  False
# Non-Fatal with highest confidence by DecisionTr...                  False
# Non-Fatal with highest confidence by NeuralNetw...                  False
# Non-Fatal with highest confidence by RandomFore...                  False
# Non-Fatal with highest confidence by NaiveBayes...                  False
# Non-Fatal with highest confidence by SupportVec...                  False
# Non-Fatal with highest confidence by TabNetClas...                  False
# Non-Fatal with highest confidence by ExtremeGra...                  False
#
#                                                            \
#                                                      shap
# Attempted Suicide                                   False
# Mass shooting                                       False
# Fatal with highest confidence by DecisionTreeCl...  False
# Fatal with highest confidence by NeuralNetworkC...  False
# Fatal with highest confidence by RandomForestCl...  False
# Fatal with highest confidence by NaiveBayesMixe...  False
# Fatal with highest confidence by SupportVectorM...  False
# Fatal with highest confidence by TabNetClassifier   False
# Fatal with highest confidence by ExtremeGradien...  False
# Non-Fatal with highest confidence by DecisionTr...  False
# Non-Fatal with highest confidence by NeuralNetw...  False
# Non-Fatal with highest confidence by RandomFore...  False
# Non-Fatal with highest confidence by NaiveBayes...  False
# Non-Fatal with highest confidence by SupportVec...  False
# Non-Fatal with highest confidence by TabNetClas...  False
# Non-Fatal with highest confidence by ExtremeGra...  False
#
#                                                    SupportVectorMachineClassifier  \
#                                                                              lime
# Attempted Suicide                                                           False
# Mass shooting                                                               False
# Fatal with highest confidence by DecisionTreeCl...                          False
# Fatal with highest confidence by NeuralNetworkC...                          False
# Fatal with highest confidence by RandomForestCl...                          False
# Fatal with highest confidence by NaiveBayesMixe...                          False
# Fatal with highest confidence by SupportVectorM...                          False
# Fatal with highest confidence by TabNetClassifier                           False
# Fatal with highest confidence by ExtremeGradien...                          False
# Non-Fatal with highest confidence by DecisionTr...                          False
# Non-Fatal with highest confidence by NeuralNetw...                          False
# Non-Fatal with highest confidence by RandomFore...                          False
# Non-Fatal with highest confidence by NaiveBayes...                          False
# Non-Fatal with highest confidence by SupportVec...                          False
# Non-Fatal with highest confidence by TabNetClas...                          False
# Non-Fatal with highest confidence by ExtremeGra...                          False
#
#
#                                                      shap
# Attempted Suicide                                   False
# Mass shooting                                       False
# Fatal with highest confidence by DecisionTreeCl...  False
# Fatal with highest confidence by NeuralNetworkC...  False
# Fatal with highest confidence by RandomForestCl...  False
# Fatal with highest confidence by NaiveBayesMixe...  False
# Fatal with highest confidence by SupportVectorM...  False
# Fatal with highest confidence by TabNetClassifier   False
# Fatal with highest confidence by ExtremeGradien...  False
# Non-Fatal with highest confidence by DecisionTr...  False
# Non-Fatal with highest confidence by NeuralNetw...  False
# Non-Fatal with highest confidence by RandomFore...  False
# Non-Fatal with highest confidence by NaiveBayes...  False
# Non-Fatal with highest confidence by SupportVec...  False
# Non-Fatal with highest confidence by TabNetClas...  False
# Non-Fatal with highest confidence by ExtremeGra...  False

# %%
# metrics on random records (post-hoc explainers)

lime_metrics_random_df = pd.read_csv('../data/explanation_results/lime_metrics_random_records.csv', index_col=0)
shap_metrics_random_df = pd.read_csv('../data/explanation_results/shap_metrics_random_records.csv', index_col=0)

lime_metrics_random_df.columns = pd.MultiIndex.from_product([lime_metrics_random_df.columns, ['lime']])
shap_metrics_random_df.columns = pd.MultiIndex.from_product([shap_metrics_random_df.columns, ['shap']])
lime_metrics_random_df.join(shap_metrics_random_df).sort_index(level=0, axis=1)
# Out:
#                   DecisionTreeClassifier            \
#                                     lime      shap
# mean faithfulness               0.182756 -0.263450
# std faithfulness                0.167345  0.638129
#
#                   ExtremeGradientBoostingClassifier            \
#                                                lime      shap
# mean faithfulness                          0.204895 -0.319465
# std faithfulness                           0.159458  0.699578
#
#                   NeuralNetworkClassifier           RandomForestClassifier  \
#                                      lime      shap                   lime
# mean faithfulness                0.017472 -0.039935               0.244445
# std faithfulness                 0.080771  0.200060               0.139524
#
#                             SupportVectorMachineClassifier
#                        shap                           lime      shap
# mean faithfulness -0.293849                       0.092068 -0.138946
# std faithfulness   0.711163                       0.110731  0.165030
